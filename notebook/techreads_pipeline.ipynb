# %% [markdown]
# # TechReads Pipeline Notebook (CW1 Supporting File)
# This notebook references the scripts used across Tasks 1, 2, and 4.

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\scrape_techreads.py"
# Out:
# Found 58 product cards on the page
# Saved 15 records to data\techreads_books.csv
#                                                                  title           author  publication_year  price_gbp  rating                                                                                                                 product_url                   scraped_at_utc
#                                         Solutions Architect's Handbook Packt Publishing              2024        0.0     4.7                                          https://www.packtpub.com/en-gb/product/solutions-architects-handbook-9781835084366 2026-02-24T19:55:16.089826+00:00
#                              Data Engineering with Databricks Cookbook Packt Publishing              2024        0.0     4.4                              https://www.packtpub.com/en-gb/product/data-engineering-with-databricks-cookbook-9781837632060 2026-02-24T19:55:16.089826+00:00
#                                              Data Engineering with dbt Packt Publishing              2023        0.0     4.6                                              https://www.packtpub.com/en-gb/product/data-engineering-with-dbt-9781803241883 2026-02-24T19:55:16.089826+00:00
#                                            Getting Started with DuckDB Packt Publishing              2024        0.0     5.0                                            https://www.packtpub.com/en-gb/product/getting-started-with-duckdb-9781803232539 2026-02-24T19:55:16.089826+00:00
#                            Data Engineering with Google Cloud Platform Packt Publishing              2024        0.0     4.5                            https://www.packtpub.com/en-gb/product/data-engineering-with-google-cloud-platform-9781835085363 2026-02-24T19:55:16.089826+00:00
# Databricks Certified Associate Developer for Apache Spark Using Python Packt Publishing              2024        0.0     5.0 https://www.packtpub.com/en-gb/product/databricks-certified-associate-developer-for-apache-spark-using-python-9781804616208 2026-02-24T19:55:16.089826+00:00
#                          Mastering Azure Databricks for Data Engineers Packt Publishing              2024        0.0     5.0                          https://www.packtpub.com/en-gb/product/mastering-azure-databricks-for-data-engineers-9781836200437 2026-02-24T19:55:16.089826+00:00
#                                           Data Engineering with Python Packt Publishing              2020        0.0     2.6                                           https://www.packtpub.com/en-gb/product/data-engineering-with-python-9781839212307 2026-02-24T19:55:16.089826+00:00
#          Apache Spark 3 for Data Engineering and Analytics with Python Packt Publishing              2021        0.0     5.0          https://www.packtpub.com/en-gb/product/apache-spark-3-for-data-engineering-and-analytics-with-python-9781803244303 2026-02-24T19:55:16.089826+00:00
#                                          Data Quality in the Age of AI Packt Publishing              2024        0.0     2.5                                          https://www.packtpub.com/en-gb/product/data-quality-in-the-age-of-ai-9781835088562 2026-02-24T19:55:16.089826+00:00

# %%
# !pip install mysql
# Out:
# Requirement already satisfied: mysql in C:\Users\alvi9\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.0.3)
# Requirement already satisfied: mysqlclient in C:\Users\alvi9\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mysql) (2.2.8)

# %%
import pandas as pd
df = pd.read_csv(r"data/techreads_books.csv")
df.head()
# Out:
#                                          title            author  \
# 0               Solutions Architect's Handbook  Packt Publishing
# 1    Data Engineering with Databricks Cookbook  Packt Publishing
# 2                    Data Engineering with dbt  Packt Publishing
# 3                  Getting Started with DuckDB  Packt Publishing
# 4  Data Engineering with Google Cloud Platform  Packt Publishing
#
#    publication_year  price_gbp  rating  \
# 0              2024        0.0     4.7
# 1              2024        0.0     4.4
# 2              2023        0.0     4.6
# 3              2024        0.0     5.0
# 4              2024        0.0     4.5
#
#                                          product_url  \
# 0  https://www.packtpub.com/en-gb/product/solutio...
# 1  https://www.packtpub.com/en-gb/product/data-en...
# 2  https://www.packtpub.com/en-gb/product/data-en...
# 3  https://www.packtpub.com/en-gb/product/getting...
# 4  https://www.packtpub.com/en-gb/product/data-en...
#
#                      scraped_at_utc
# 0  2026-02-24T19:55:16.089826+00:00
# 1  2026-02-24T19:55:16.089826+00:00
# 2  2026-02-24T19:55:16.089826+00:00
# 3  2026-02-24T19:55:16.089826+00:00
# 4  2026-02-24T19:55:16.089826+00:00

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\csv_to_json.py"
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\mongodb_pipeline.py"
# Out:
# Created JSON file: data\techreads_books.json (15 records)
# Inserted 15 documents into techreads_mongo_db.books
# Mongo query returned 12 records in 0.632 ms
# {'title': 'Getting Started with DuckDB', 'price_gbp': 0.0, 'rating': 5.0}
# {'title': 'Databricks Certified Associate Developer for Apache Spark Using Python', 'price_gbp': 0.0, 'rating': 5.0}
# {'title': 'Mastering Azure Databricks for Data Engineers', 'price_gbp': 0.0, 'rating': 5.0}
# {'title': 'Apache Spark 3 for Data Engineering and Analytics with Python', 'price_gbp': 0.0, 'rating': 5.0}
# {'title': 'Mastering Azure Databricks for Data Engineers', 'price_gbp': 0.0, 'rating': 5.0}
# Mongo query with index: 0.500 ms

# %%
pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in c:\users\alvi9\anaconda3\lib\site-packages (2.2.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\benchmark_sql_vs_nosql.py"
# Out:
# === SQL vs NoSQL Query Time Comparison ===
# MySQL query time   : 0.388 ms
# MongoDB query time : 3.668 ms
# Observation: MySQL was faster in this local test run.
