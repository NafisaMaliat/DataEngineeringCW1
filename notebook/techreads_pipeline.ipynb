# %% [markdown]
# # TechReads Pipeline Notebook (CW1 Supporting File)
# This notebook references the scripts used across Tasks 1, 2, and 4.

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\scrape_techreads.py"
# Out:
# Saved 15 records to data\techreads_books.csv
#                                 title  author publication_year  price_gbp  rating availability                                                                              product_url                   scraped_at_utc
#                  A Light in the Attic Unknown             None      51.77       3     In stock                https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html 2026-02-19T14:10:55.880641+00:00
#                    Tipping the Velvet Unknown             None      53.74       1     In stock                   https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html 2026-02-19T14:10:55.880641+00:00
#                            Soumission Unknown             None      50.10       1     In stock                           https://books.toscrape.com/catalogue/soumission_998/index.html 2026-02-19T14:10:55.880641+00:00
# ...

# %%
# !pip install mysql

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\alvi9\MyWork\Data Engineering\techreads_books.csv")
df.head()
# Out:
#                                    Title  Price  Star Rating Availability  \
# 0                   A Light in the Attic  51.77            3     In stock
# 1                     Tipping the Velvet  53.74            1     In stock
# 2                             Soumission  50.10            1     In stock
# 3                          Sharp Objects  47.82            4     In stock
# 4  Sapiens: A Brief History of Humankind  54.23            5     In stock
#
#                 UPC
# 0  a897fe39b1053632
# 1  90fa61229261140a
# 2  6957f44c3847a760
# 3  e00eb4fd7b871a48
# 4  4165285e1663650f

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\csv_to_json.py"
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\mongodb_pipeline.py"
# Out:
# Created JSON file: data\techreads_books.json (15 records)
# Inserted 15 documents into techreads_mongo_db.books
# Mongo query returned 5 records in 1.419 ms
# {'title': 'Set Me Free', 'price_gbp': 17.46, 'rating': 5}
# {'title': 'Rip it Up and Start Again', 'price_gbp': 35.02, 'rating': 5}
# {'title': "Shakespeare's Sonnets", 'price_gbp': 20.66, 'rating': 4}
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price_gbp': 22.6, 'rating': 4}
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price_gbp': 33.34, 'rating': 4}
# Mongo query with index: 1.275 ms

# %%
pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
# ...

# %%
# !python "C:\Users\alvi9\MyWork\Data Engineering - Copy\src\benchmark_sql_vs_nosql.py"
# Out:
# === SQL vs NoSQL Query Time Comparison ===
# MySQL query time   : 0.690 ms
# MongoDB query time : 4.218 ms
# Observation: MySQL was faster in this local test run.
